# %% [markdown]
# <img align="center" src="figures/course.png" width="800">
#
# #                                    16720 (B) Bag of Visual Words - Assignment 2
#
#      Instructor: Kris Kitani                      TAs:Paritosh (Lead), Rawal, Yan, Zen, Wen-Hsuan, Qichen

# %% [markdown]
# ## Building a Recognition System
# We have formed a convenient way to represent images for recognition. We will now produce a basic recognition system with spatial pyramid matching. The goal of the system is presented in Fig. 1:
# given an image, classify (\ie recognize/name) the scene where the image was taken.
#
# Traditional classification problems follow two phases: training and testing.
# At training time, the computer is given a pile of formatted data (\ie, a collection
# of feature vectors) with corresponding labels (\eg, ``desert``, ``kitchen``) and
# then builds a model of how the data relates to the labels:
# ``if green, then kitchen``. At test time, the computer takes features and uses these rules to infer the label:
# \eg, ``this is green, so therefore it is kitchen``.
#
# In this assignment, we will use the simplest classification model: nearest neighbor.
# At test time, we will simply look at the query's nearest neighbor in the training set
# and transfer that label. In this example, you will be looking
# at the query image and
# looking up its nearest neighbor in a collection of training images whose labels are already known. This approach works
# surprisingly well given a huge amount of data, \eg, a very cool graphics applications from [1].
#
# The key components of any nearest-neighbor system are:
# * $features$ (how do you represent your instances?)
# * $similarity$ (how do you compare instances in the feature space?)
#
# You will implement both in this section.

# %%
import nbimporter
import numpy as np
import skimage
import multiprocessing
import threading
import queue
import os,time
import math
from p1 import get_visual_words
from skimage import io
import matplotlib.pyplot as plt

# %% [markdown]
# import nbimporter
# import numpy as np
# import skimage
# import multiprocessing
# import threading
# import queue
# import os,time
# import math
# from ipynb.fs.defs.p1 import get_visual_words

# %% [markdown]
# ## For Autograding P2, ensure uploading `trained_system.npz`

# %% [markdown]
# ### Q2.1 (10 Points -> 5 Autograder + 5 WriteUp)
# We will first represent an image with a bag of words approach. In each image, we simply look at
# how often each word appears.
#
# Write the function
# ```
#             def get_feature_from_wordmap(wordmap,dict_size):
# ```
# that extracts the histogram (Look into ``numpy.histogram()``) of visual words within the given image
# (\ie, the bag of visual words).
# As inputs, the function will take:
#
# * $wordmap$ is a $H$ $\times$ $W$ image containing the IDs of the visual words
# * $dict\_size$ is the maximum visual word ID (\ie, the number of visual words, the dictionary size). Notice that your histogram should have $dict\_size$ bins, corresponding to how often that each word occurs.
#
# As output, the function will return $hist$, a $dict\_size$ histogram that is $L_1$ normalized, (i.e., the sum equals $1$).

# %%
def get_feature_from_wordmap(wordmap, dict_size):
    '''
    Compute histogram of visual words.

    [input]
    * wordmap: numpy.ndarray of shape (H,W)
    * dict_size: dictionary size K

    [output]
    * hist: numpy.ndarray of shape (K)
    '''
    
    '''
    HINTS:
    (1) We can use np.histogram with flattened wordmap
    '''
    
    hist, bin_ed = np.histogram(wordmap.flatten(),np.arange(dict_size+1), density=True)
    #print(bin_ed)
    hist = hist / np.sum(hist)
    #hist = np.reshape(hist,(1,dict_size))
    # ----- TODO -----
    # YOUR CODE HERE
    #raise NotImplementedError()
    #print(hist)
#     fig, ax = plt.subplots()
#     ax.plot(bin_ed[:-1], hist)
#     ax.title.set_text("Visualize Histogram")
#     plt.show()
    
    hist = np.reshape(hist,(-1))
    #print(hist.shape)
    return hist

# %%
path_img1 = "./data/aquarium/sun_aairflxfskjrkepm.jpg"
path_img2 ="./figures/textons/conference_room.jpg"
path_img3 ="./figures/textons/gas_station.jpg"
path_img4 ="./data/laundromat/sun_aeyuobflqlynijyl.jpg"
path_img5 = "./data/windmill/sun_bbtucfxxfnzkzqbb.jpg"

img1 = io.imread(path_img1)
img2 = io.imread(path_img2)
img3 = io.imread(path_img3)
img4 = io.imread(path_img4)
img5 = io.imread(path_img5)

img1 = img1.astype('float') / 255
img2 = img2.astype('float') / 255
img3 = img3.astype('float') / 255
img4 = img4.astype('float') / 255
img5 = img5.astype('float') / 255

#img = img.astype('float')/255
#img = skimage.color.rgb2gray(img)
dictionary= np.load('dictionary.npy')
print(dictionary.shape)
dict_size = dictionary.shape[0]
# Out:
# (200, 60)

# %%
wordmap1= get_visual_words(img1, dictionary)
plt.imshow(wordmap1, cmap="rainbow")
# Out:
# shape:  (309, 500, 12)
# 60

# %%
hist = get_feature_from_wordmap(wordmap1, dict_size)
bin_ed = np.arange(dict_size+1)
fig, ax = plt.subplots()
ax.plot(bin_ed[:-1], hist)
plt.xlabel("Visual Words positions")
plt.ylabel("Frequency of visual words")
ax.title.set_text("Visualize Histogram")
plt.show()

# %%
wordmap2= get_visual_words(img2, dictionary)
plt.imshow(wordmap2, cmap="rainbow")
# Out:
# shape:  (375, 500, 12)
# 60

# %%
hist = get_feature_from_wordmap(wordmap2, dict_size)
bin_ed = np.arange(dict_size+1)
fig, ax = plt.subplots()
plt.xlabel("Visual Words positions")
plt.ylabel("Frequency of visual words")
ax.plot(bin_ed[:-1], hist)
ax.title.set_text("Visualize Histogram")
plt.show()

# %%
wordmap3= get_visual_words(img3, dictionary)
plt.imshow(wordmap3, cmap="rainbow")
# Out:
# shape:  (334, 500, 12)
# 60

# %%
get_feature_from_wordmap(wordmap3, dict_size)
bin_ed = np.arange(dict_size+1)
fig, ax = plt.subplots()
plt.xlabel("Visual Words positions")
plt.ylabel("Frequency of visual words")
ax.plot(bin_ed[:-1], hist)
ax.title.set_text("Visualize Histogram")
plt.show()

# %%
wordmap4= get_visual_words(img4, dictionary)
plt.imshow(wordmap4, cmap="rainbow")
# Out:
# shape:  (500, 334, 12)
# 60

# %%
hist = get_feature_from_wordmap(wordmap4, dict_size)
bin_ed = np.arange(dict_size+1)
fig, ax = plt.subplots()
plt.xlabel("Visual Words positions")
plt.ylabel("Frequency of visual words")
ax.plot(bin_ed[:-1], hist)
ax.title.set_text("Visualize Histogram")
plt.show()

# %%
wordmap5= get_visual_words(img5, dictionary)
plt.imshow(wordmap5, cmap="rainbow")
# Out:
# shape:  (375, 500, 12)
# 60

# %%
hist = get_feature_from_wordmap(wordmap5, dict_size)
bin_ed = np.arange(dict_size+1)
fig, ax = plt.subplots()
plt.xlabel("Visual Words positions")
plt.ylabel("Frequency of visual words")
ax.plot(bin_ed[:-1], hist)
ax.title.set_text("Visualize Histogram")
plt.show()

# %% [markdown]
# <font color="blue">**For 5 Images, load visual word maps, visualize their histogram, and include it in the write up.**</font> This will help you verifying that your function is working correctly before proceeding.

# %% [markdown]
# ### Multi-resolution: Spatial Pyramid Matching
#
# Bag of words is simple and efficient, but it discards information about the spatial structure of the image and this information is often valuable. One way to alleviate this issue is to use spatial pyramid matching [2]. The general idea is to divide the image into a small number of cells, and concatenate the histogram of each of these cells to the histogram of the original image, with a suitable weight.
#
# Here we will implement a popular scheme that chops the image into $2^l\times2^l$ cells where $l$ is the layer number. We treat each cell as a small image and count how often each visual word appears. This results in a histogram for every single cell in every layer. Finally to represent the entire image, we concatenate all the histograms together. If there are $L+1$ layers and $K$ visual words, the resulting vector has dimensionality $K\sum_{l=0}^L{4^l} = K\left(4^{(L+1)}-1\right)/3$.
#
# Now comes the weighting scheme. Note that when concatenating all the histograms, histograms from different levels are assigned different weights. Typically (and in the original work [2]), features from layer $l$ gets half the weight of features from layer $l+1$, with the exception of layer 0, which is assigned a weight equal to layer 1. A popular choice is for layer $0$ and layer $1$ the weight is set to $2^{-L}$, and for the rest it is set to $2^{l-L-1}$ (\eg, in a three layer spatial pyramid, $L=2$ and weights are set to $1/4$, $1/4$ and $1/2$ for layer 0, 1 and 2 respectively, see Fig. 7). Take level 2 as an example, there will be 16 histograms in total, each has a norm equal to one. You should concatenate these histograms, normalize this layer (multiply the concatenated vector by 1/16), and apply the 1/2 layer weight of level 2 on top of that. Note that following this operation, concatenating the weighted features of each layer will result in a final vector of norm equal to 1.
#
# <img align="center" src="figures/spm.jpg" width="800">
# <figcaption align = "center"><b>Figure 7. Spatial Pyramid Matching: From [2]. Toy example of a pyramid for L = 2. The image has three visual words, indicated by circles, diamonds, and crosses. We subdivide the image at three different levels of resolution. For each level of resolution and each channel, we count the features that fall in each spatial bin. Finally, weight each spatial histogram.}</b></figcaption>

# %% [markdown]
# ### Q2.2.1 (15 Points Autograder)
#
# Create a function that form a multi-resolution representation of the given image.
# ```
#             def get_feature_from_wordmap_SPM(wordmap,layer_num,dict_size):
# ```
# As inputs, the function will take:
#
# * **layer_num** the number of layers in the spatial pyramid, \ie, $L+1$
# * **wordmap** is a $H$ $\times$ $W$ image containing the IDs (\ie index) of the visual words
# * **dict_size** is the maximum visual word ID (\ie, the number of visual words, the dictionary size)
#
# As output, the function will return hist_all, a vector that is $L_1$ normalized. **Please use a 3-layer spatial pyramid ($L=2$) for all the following recognition tasks.**
#
# One small hint for efficiency: a lot of computation can be saved if you first compute the histograms of the _finest layer_, because the histograms of coarser layers can then be aggregated from finer ones. Make sure you normalize the histogram after aggregation.
#
# **Note for Autograder :** Ensure that final $hist\_all$ (the output of `get_feature_from_wordmap_SPM`) has histogram features arranged from Loweset Level (global features) to Highest Level (finest features). Example: the output array should **first contain the histogram for Level 0, followed by Level 1, and then Level 2**.

# %%
def get_feature_from_wordmap_SPM(wordmap, layer_num, dict_size):
    '''
    Compute histogram of visual words using spatial pyramid matching.

    [input]
    * wordmap: numpy.ndarray of shape (H,W)
    * layer_num: number of spatial pyramid layers
    * dict_size: dictionary size K

    [output]
    * hist_all: numpy.ndarray of shape (K*(4^layer_num-1)/3)
    '''
    '''
    HINTS:
    (1) Take care of Weights 
    (2) Try to build the pyramid in Bottom Up Manner
    (3) the output array should first contain the histogram for Level 0 (top most level) , followed by Level 1, and then Level 2.
    '''
    # ----- TODO -----
    h, w = wordmap.shape
    L = layer_num - 1
    patch_width = math.floor(w / (2**L))
    patch_height = math.floor(h / (2**L))
    L_col = 2**L
    L_row = 2**L
    '''
    HINTS:
    1.> create an array of size (dict_size, (4**(L + 1) -1)/3) )
    2.> pre-compute the starts, ends and weights for the SPM layers L 
    '''
    weights =[]
    #output = np.zeros(( L+1, dict_size))
    output=[]
    for l in range(L+1):
        if l ==0 or l==1:
            weights.append(2**(-(L)))
        else:
            weights.append(2**(l-(L+1)))
    # YOUR CODE HERE
    #raise NotImplementedError()
    '''
    HINTS:
    1.> Loop over the layers from L to 0
    2.> Handle the base case (Layer L) separately and then build over that
    3.> Normalize each histogram separately and also normalize the final histogram
    '''
    print(dict_size) 
    for l in range(L, -1, -1):
        output_new=[]
        hist_new=[]
        n_col = 2**l
        n_row = 2**l
        patch_w = math.floor(w / (2**l))
        patch_h = math.floor(h / (2**l)) 
        stride = int(L_col/n_col) #This defines the rate at which concat should cover at each level
        #ignoring the row as its square matrix
        if l == L:
            hist_L = np.zeros((L_row, L_col, dict_size))
            for i in range(L_row):
                for j in range(L_col):
                    pix_vword = wordmap[i*patch_h: (i+1)*patch_h, j*patch_w : (j+1)*patch_w ]
                    hist = get_feature_from_wordmap(pix_vword,dict_size)
                    hist_L[i,j,:] = hist
                    output= np.hstack([output, hist*weights[l]])
            #print("flage 0 :", output.shape)
        #for loop for rest of the layers using the histogram of Lth layer hist_L
        else:
            
            for i in range(n_row):
                for j in range(n_col):
                    hist_new = np.concatenate((hist_L[stride*i:stride*(i+1),stride*j:stride*(j+1),: ]))
                    hist_new = np.sum(hist_new, axis = 0)
                    #print("flag histnew: ", hist_new.shape)
                    hist_new = np.reshape(hist_new,(-1))
                    #hist_new = hist_new.flatten()
                    #print("flag 1: ", hist_new.shape)
                    output_new= np.hstack([output_new, hist_new*weights[l]])
                    #print("flag 3 :", output_new.shape)
            #print("flag 4 :", output_new.shape)
        output= np.hstack([output_new, output])
        #print("flag 5 :", output.shape)
    
    hist_all = output
    hist_all = hist_all/np.sum(hist_all)
    
    return hist_all

# %%
# hist_all = get_feature_from_wordmap_SPM(wordmap1, 3, dict_size)
# fig, ax = plt.subplots()
# bin_ed = np.arange(hist_all.shape[0]+1)
# ax.plot(bin_ed[:-1], hist_all)
# ax.title.set_text("Visualize Histogram_all")
# plt.show()
# print(hist_all.shape); print(dict_size*((4**3) -1)/3)

# %% [markdown]
# ### 2.3 Comparing images
#
#
# We will also need a way of comparing images to find the _nearest_ instance in the training data. In this assignment, we'll use the histogram intersection similarity. The histogram intersection similarity between two histograms is the sum of the minimum value of each corresponding bins.
#
# Note that since this is a similarity, you want the $largest$ value to find the _nearest_ instance.
#
# #### Q2.3.1 (10 Points Autograder)
# Create the function
# ```
#                 def distance_to_set(word_hist,histograms):
# ```
# where $word\_hist$ is a $K\left(4^{(L+1)}-1\right)/3$ vector and $histograms$ is a $T \times K\left(4^{(L+1)}-1\right)/3$ matrix containing $T$ features from $T$ training samples concatenated along the rows. This function returns the histogram intersection similarity between $word\_hist$ and each training sample as a vector of length $T$. Since this is called every time you want to look up a classification, you want this to be fast, so doing a for-loop over tens of thousands of histograms is a very bad idea.

# %%
def distance_to_set(word_hist, histograms):
    '''
    Compute similarity between a histogram of visual words with all training image histograms.

    [input]
    * word_hist: numpy.ndarray of shape (K)
    * histograms: numpy.ndarray of shape (N,K)

    [output]
    * sim: numpy.ndarray of shape (N)
    '''
    '''
    HINTS:
    (1) Consider A = [0.1,0.4,0.5] and B = [[0.2,0.3,0.5],[0.8,0.1,0.1]] then \
        similarity between element A and set B could be represented as [[0.1,0.3,0.5],[0.1,0.1,0.1]]   
    '''
    intersection = np.minimum(word_hist, histograms)
    sim = np.sum(intersection,axis = 1)
    # ----- TODO -----
    # YOUR CODE HERE
    #raise NotImplementedError()
    return sim

# %% [markdown]
# #### Q2.4 Building a Model of the Visual World
#
# Now that we've obtained a representation for each image, and defined a similarity measure to compare two spatial pyramids, we want to put everything up to now together.
#
# You will need to load the training file names from `data/train_data.npz` and the filter bank and visual word dictionary from `dictionary.npy`.
# You will save everything to a `.npz` numpy-formated (use `np.savez`) file named `trained_system.npz`. Included will be:
#
#
# 1. $dictionary$: your visual word dictionary.
# 2. $features$: a $N \times  K\left(4^{(L+1)}-1\right)/3$ matrix containing all of the histograms of the $N$ training images in the data set. A dictionary with $150$ words will make a ``train_features`` matrix of size $1000 \times 3150$.
# 3. $labels$: an $N$ vector containing the labels of each of the images. ( ``features[i]`` will correspond to label ``labels[i]``).
# 4. $SPM\_layer\_num$: the number of spatial pyramid layers you used to extract the features for the training images.
#
# We have provided you with the names of the training images in ``data/train_data.npz``.
# You want to use the dictionary entry ``image_names`` for training.
# You are also provided the names of the test images in ``data/test_data.npz``, which is structured in the same way as the training data; however, _you cannot use the testing images for training._
#
# If it's any helpful, the below table lists the class names that correspond to the label indices:
#
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: |
# |aquarium | park | desert | highway | kitchen | laundromat | waterfall | windmill|

# %% [markdown]
# #### Q2.4.1 (15 Points Autograder)
# Implement the function
# ```
#                 def build_recognition_system():
# ```
# that produces ``trained_system.npz``.
#
# Implement
# ```
#                 def get_image_feature(file_path,dictionary,layer_num,K):
# ```
# that load image, extract word map from the image, compute SPM feature and return the computed feature. Use this function in your ``build_recognition_system()``.

# %%
def get_image_feature(file_path, dictionary, layer_num, K):
    '''
    Extracts the spatial pyramid matching feature.

    [input]
    * file_path: path of image file to read
    * dictionary: numpy.ndarray of shape (K,3F)
    * layer_num: number of spatial pyramid layers
    * K: number of clusters for the word maps

    [output]
    * feature: numpy.ndarray of shape (K*(4^layer_num-1)/3)
    '''
    img = io.imread(file_path)
    img = img.astype('float') / 255
    wordmap= get_visual_words(img, dictionary)
    dict_size = dictionary.shape[0]
    feature = get_feature_from_wordmap_SPM(wordmap, layer_num, dict_size)
    
    # ----- TODO -----
    # YOUR CODE HERE
    #raise NotImplementedError()
    return [file_path, feature]

# %%
def build_recognition_system(num_workers=2):
    
    from joblib import Parallel, delayed
    '''
    Creates a trained recognition system by generating training features from all training images.

    [input]
    * num_workers: number of workers to process in parallel

    [saved]
    * features: numpy.ndarray of shape (N,M)
    * labels: numpy.ndarray of shape (N)
    * dictionary: numpy.ndarray of shape (K,3F)
    * SPM_layer_num: number of spatial pyramid layers
    '''

    SPM_layer_num = 3
    train_data = np.load("./data/train_data.npz")
    dictionary = np.load("dictionary.npy")
    K = dictionary.shape[0]
    image_names = train_data['files']
    labels = train_data['labels']
    C= int(K*(4**SPM_layer_num-1)/3)
    num_images = image_names.shape[0]
    list_of_args = []
    features=np.zeros((0, C))
    for i in range(num_images):
        print(image_names[i])
        full_image_path = './data/' + image_names[i]
        list_of_args.append([full_image_path, dictionary, SPM_layer_num, K ])
        file_path, ordered_features = get_image_feature(full_image_path, dictionary, SPM_layer_num, K )
       
        ordered_features = np.asarray(ordered_features)
        #print("Shape of Ordered Feature: ", ordered_features.shape)
        ordered_features = np.reshape(ordered_features,(1, -1))
        print("Shape of Ordered Feature: ", ordered_features.shape)
        #print("Shape of Feature: ", features.shape)
        features = np.vstack((features, ordered_features))
        print("Shape of Feature: ", features.shape)
        #print("matrix of Feature: ", features, "\n")
    #file_path, ordered_features = Parallel(n_jobs=2)(delayed(get_image_feature)(input) for input in list_of_args)   

    #p = multiprocessing.Pool(processes=num_workers)
    # ----- TODO -----
    # YOUR CODE HERE
    #raise NotImplementedError()
    np.savez('trained_system.npz', features=features,
                                    labels=labels,
                                    dictionary=dictionary,
                                    SPM_layer_num=SPM_layer_num)

# %%
#build_recognition_system(num_workers=2)
# Out:
# windmill/sun_agudhwulyxcizdjv.jpg
# shape:  (500, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (1, 4200)
# laundromat/sun_aodzngrfoqxcuxiq.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (2, 4200)
# park/labelme_fjcqebsjrjqaxut.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (3, 4200)
# windmill/sun_bxmomsywaroyoivk.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (4, 4200)
# desert/sun_adjlepvuitklskrz.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (5, 4200)
# kitchen/sun_alouvjfpycbghnrv.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (6, 4200)
# park/labelme_zvxznjrjrujetsi.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (7, 4200)
# park/sun_aoobcgvishcodase.jpg
# shape:  (338, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (8, 4200)
# windmill/sun_bratfupeyvlazpba.jpg
# shape:  (500, 376, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (9, 4200)
# park/labelme_umockakjmtudpaz.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (10, 4200)
# windmill/sun_btagmtoojkghfpnw.jpg
# shape:  (341, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (11, 4200)
# highway/sun_bopyvzhpgvcivlcv.jpg
# shape:  (186, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (12, 4200)
# kitchen/sun_aixacgstjgjpkhyx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (13, 4200)
# aquarium/sun_djtzmipoyykmljju.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (14, 4200)
# aquarium/sun_afxyzryqccpvazhi.jpg
# shape:  (320, 240, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (15, 4200)
# desert/sun_bysxtveirarlnhrs.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (16, 4200)
# desert/sun_bbecprdjqdlnqovb.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (17, 4200)
# park/labelme_jsjzaunwfazsmjx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (18, 4200)
# windmill/sun_bbhwehaaapkoyhqm.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (19, 4200)
# windmill/sun_bsngeuxxmgmcsesp.jpg
# shape:  (376, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (20, 4200)
# park/labelme_zbyarunxxqdfebc.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (21, 4200)
# windmill/sun_aszoiltmpeptbfwt.jpg
# shape:  (379, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (22, 4200)
# kitchen/sun_aqtwemskfyhpopqf.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (23, 4200)
# desert/sun_avtmqreqkvhyoead.jpg
# shape:  (310, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (24, 4200)
# waterfall/sun_axtdifylvevxuxbx.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (25, 4200)
# aquarium/sun_axgloeychjvfslqg.jpg
# shape:  (324, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (26, 4200)
# aquarium/sun_amawmmnqmdlmtoib.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (27, 4200)
# waterfall/sun_axetyutyqwxfhnkk.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (28, 4200)
# kitchen/sun_aaqawxqotnzysend.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (29, 4200)
# kitchen/sun_aryemauxglpckieh.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (30, 4200)
# waterfall/sun_auiludrcnujfudca.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (31, 4200)
# highway/sun_bzyamrwsvrlynfra.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (32, 4200)
# laundromat/sun_avvseajawqnwrhdy.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (33, 4200)
# highway/sun_bxlisjszhebiljnh.jpg
# shape:  (332, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (34, 4200)
# laundromat/sun_aoehirsmpbzmkjyx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (35, 4200)
# waterfall/sun_aubqmdekaxxzvkig.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (36, 4200)
# aquarium/sun_albheujeaogefcsy.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (37, 4200)
# kitchen/sun_axnntffdgqnpixyj.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (38, 4200)
# waterfall/sun_aqwtkzdbuyzjiklf.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (39, 4200)
# laundromat/sun_adlafxocmfshpufq.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (40, 4200)
# windmill/sun_bztzybuytupmhcbl.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (41, 4200)
# highway/sun_bebjsikreyhhhefp.jpg
# shape:  (279, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (42, 4200)
# park/sun_argnmdrhdmnzdmza.jpg
# shape:  (270, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (43, 4200)
# kitchen/sun_aomzbprctpzqwjzj.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (44, 4200)
# waterfall/sun_apjthvdrlhsmywmi.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (45, 4200)
# highway/sun_ahzbishmbqbogwvn.jpg
# shape:  (190, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (46, 4200)
# desert/sun_aqfvjhyfqgvkdkhp.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (47, 4200)
# windmill/sun_bduslxfzlbxlllnz.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (48, 4200)
# highway/sun_bneucacgncklitdg.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (49, 4200)
# aquarium/sun_ankggxiristwxewe.jpg
# shape:  (500, 333, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (50, 4200)
# highway/sun_bhskykvozosdnhzg.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (51, 4200)
# highway/sun_bqynxpovjqjgagth.jpg
# shape:  (357, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (52, 4200)
# laundromat/sun_agbozusfrwxzcwdg.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (53, 4200)
# park/labelme_xtldypihnvywonn.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (54, 4200)
# highway/sun_adaebhgozgdowgng.jpg
# shape:  (313, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (55, 4200)
# windmill/sun_bqnbhwtdwvplkifv.jpg
# shape:  (313, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (56, 4200)
# desert/sun_bflpurrifjtqudae.jpg
# shape:  (332, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (57, 4200)
# kitchen/sun_anaaafpyeqdsnimg.jpg
# shape:  (409, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (58, 4200)
# highway/sun_apccrwjexoyshfqe.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (59, 4200)
# desert/sun_bnepazmfgafaabrs.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (60, 4200)
# highway/sun_asexmybwhofzjwno.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (61, 4200)
# kitchen/sun_abubevclcmcjqgae.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (62, 4200)
# highway/sun_beakjawckqywuhzw.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (63, 4200)
# kitchen/sun_avtdeaxixgmwquck.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (64, 4200)
# kitchen/sun_aqajjgvroevxtecg.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (65, 4200)
# desert/sun_bblpdgabxhhyyyvh.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (66, 4200)
# laundromat/sun_akwrkpzadigturfj.jpg
# shape:  (342, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (67, 4200)
# waterfall/sun_akvekvlcibmjxdeu.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (68, 4200)
# aquarium/sun_aqvxaubaksemgsnj.jpg
# shape:  (320, 240, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (69, 4200)
# windmill/sun_baueqhsqpjpjuhfz.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (70, 4200)
# desert/sun_bbcfpwlpolnutyju.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (71, 4200)
# desert/sun_bnrpatoccuvbbkip.jpg
# shape:  (319, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (72, 4200)
# park/labelme_fzfkkjbyygrtdij.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (73, 4200)
# park/sun_aoyffqxeiwrlgllj.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (74, 4200)
# highway/sun_bregejohubxtyyts.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (75, 4200)
# desert/sun_bqqdmfnqycjyhvuq.jpg
# shape:  (233, 348, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (76, 4200)
# park/sun_ajiqxnochaocumaa.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (77, 4200)
# desert/sun_bfpgphrzsbeqlsrv.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (78, 4200)
# kitchen/sun_aqmitamtngunumli.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (79, 4200)
# windmill/sun_bgberbtekrbujrju.jpg
# shape:  (281, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (80, 4200)
# kitchen/sun_afqpfzmhhuegedtn.jpg
# shape:  (336, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (81, 4200)
# waterfall/sun_aykjttpjrbrmvtip.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (82, 4200)
# kitchen/sun_ajhyqzpcqdztndcc.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (83, 4200)
# aquarium/sun_adtazuhapgwbydoi.jpg
# shape:  (211, 320, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (84, 4200)
# desert/sun_bwbeayteffpmoluy.jpg
# shape:  (327, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (85, 4200)
# highway/sun_boyvqutltxispgdo.jpg
# shape:  (373, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (86, 4200)
# kitchen/sun_aqgfsnmzvlkqgoqe.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (87, 4200)
# laundromat/sun_aqzwktikpmgmhmwo.jpg
# shape:  (335, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (88, 4200)
# waterfall/sun_akgrwhipyselyhhk.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (89, 4200)
# aquarium/sun_advjjmdowgagrbgu.jpg
# shape:  (314, 499, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (90, 4200)
# highway/sun_azlzqkqfwawmonwc.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (91, 4200)
# highway/sun_bbpbqltzfnykdhtp.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (92, 4200)
# waterfall/sun_acjicpxnwqghfsck.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (93, 4200)
# park/sun_azdmqekrrqjjjmsr.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (94, 4200)
# highway/sun_bfotjzzlosvcgfpx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (95, 4200)
# kitchen/sun_akndyxefbqzbqsqy.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (96, 4200)
# desert/sun_afirahbsfbhjovyq.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (97, 4200)
# laundromat/sun_aupvivznqwzxrsjd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (98, 4200)
# park/sun_beoixpbmdaobqqpo.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (99, 4200)
# waterfall/sun_bckysqrmhqchvfyi.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (100, 4200)
# windmill/sun_bjtnzdtbdwmpvnfb.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (101, 4200)
# laundromat/sun_abmjucshdypizvwx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (102, 4200)
# highway/sun_avpwctedcdxoikod.jpg
# shape:  (373, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (103, 4200)
# aquarium/sun_aegjsohwfecizxjd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (104, 4200)
# windmill/sun_adotnsaifoooswkf.jpg
# shape:  (500, 400, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (105, 4200)
# highway/sun_bzxvsmribzuahnvp.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (106, 4200)
# laundromat/sun_aipweurvvfckgwen.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (107, 4200)
# laundromat/sun_akvqlfoichimeidv.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (108, 4200)
# laundromat/sun_awoznefdnxfulxof.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (109, 4200)
# kitchen/sun_ajmwiafzffjerzeb.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (110, 4200)
# park/sun_awjwcvwwrigebqhp.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (111, 4200)
# windmill/sun_bmslenpvdkobbdrq.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (112, 4200)
# desert/sun_bpvkcqarkipjxuxl.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (113, 4200)
# windmill/sun_bmqfsnleuaxaaaid.jpg
# shape:  (500, 321, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (114, 4200)
# desert/sun_anytotdzuqbvmbmr.jpg
# shape:  (480, 335, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (115, 4200)
# waterfall/sun_bbeqjdnienanmmif.jpg
# shape:  (225, 300, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (116, 4200)
# waterfall/sun_atbqlpamixagydtc.jpg
# shape:  (346, 234, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (117, 4200)
# windmill/sun_beyrzlccgymbzsyh.jpg
# shape:  (500, 371, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (118, 4200)
# park/sun_axbudwgctcacrtpd.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (119, 4200)
# windmill/sun_brtfrfdsrpiiyrqs.jpg
# shape:  (500, 323, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (120, 4200)
# desert/sun_anpufnjkjvjhaaza.jpg
# shape:  (226, 385, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (121, 4200)
# windmill/sun_bggvngfcgbsbyuie.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (122, 4200)
# aquarium/sun_ackffcrfuhrobpeb.jpg
# shape:  (225, 300, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (123, 4200)
# laundromat/sun_arhskcrgwkddthtx.jpg
# shape:  (337, 450, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (124, 4200)
# aquarium/sun_awgplcderwsdwkqd.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (125, 4200)
# highway/sun_bvoqrgcplsuyobvx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (126, 4200)
# highway/sun_bejktkrdtjvdxhpz.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (127, 4200)
# desert/sun_afferxhafrjnpuri.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (128, 4200)
# waterfall/sun_birgtjgkuuanpoif.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (129, 4200)
# park/sun_bacaempvwbckqgqk.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (130, 4200)
# laundromat/sun_axerfulyljttavwp.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (131, 4200)
# desert/sun_bgajyjtnvisnmrfr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (132, 4200)
# waterfall/sun_aycecmbtlroslsja.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (133, 4200)
# laundromat/sun_asidrmrsxqwepjdn.jpg
# shape:  (374, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (134, 4200)
# aquarium/sun_avwxtxzmduecjnfh.jpg
# shape:  (500, 399, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (135, 4200)
# kitchen/sun_altetwarotepnrsv.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (136, 4200)
# park/labelme_nvvhwnodyafezpm.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (137, 4200)
# desert/sun_bgxdpfaslafhprgy.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (138, 4200)
# park/sun_azjxvhujajzyljub.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (139, 4200)
# windmill/sun_bkynaidrxvyincru.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (140, 4200)
# aquarium/sun_aoktasrtzmmkjadm.jpg
# shape:  (400, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (141, 4200)
# highway/sun_bujhcdwohakmipjy.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (142, 4200)
# aquarium/sun_akhuvtsqontzwtbo.jpg
# shape:  (216, 417, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (143, 4200)
# aquarium/sun_aenghfgequsylzkc.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (144, 4200)
# windmill/sun_bqoiufnufdfwevcf.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (145, 4200)
# park/labelme_earnkljoflmdqyb.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (146, 4200)
# waterfall/sun_ajkybsokdhevbyaw.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (147, 4200)
# park/labelme_mablpkssqkjazdf.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (148, 4200)
# aquarium/sun_admhjhrxakhjzgfo.jpg
# shape:  (274, 385, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (149, 4200)
# waterfall/sun_avffvgbseucjdior.jpg
# shape:  (256, 257, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (150, 4200)
# highway/sun_bpliodmwmwdjkxpf.jpg
# shape:  (332, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (151, 4200)
# highway/sun_andjvkcmoycbulcc.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (152, 4200)
# waterfall/sun_arqvtvekytgvgqjx.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (153, 4200)
# desert/sun_bbqacusxjthihjvd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (154, 4200)
# park/sun_akfipxerweccvdue.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (155, 4200)
# windmill/sun_binbxnwxgeywaqwi.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (156, 4200)
# park/labelme_osdjhxekskvwsiw.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (157, 4200)
# highway/sun_bmjizcavvsculkfz.jpg
# shape:  (277, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (158, 4200)
# desert/sun_ajqkymqgzhkwrpte.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (159, 4200)
# windmill/sun_bljvvarbzchpbtqt.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (160, 4200)
# park/labelme_zoysmqxfkzkrxzq.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (161, 4200)
# park/sun_acrohkaoxymzhizd.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (162, 4200)
# waterfall/sun_aylreebvqmfjlykr.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (163, 4200)
# park/sun_bephmlimugadmfav.jpg
# shape:  (212, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (164, 4200)
# laundromat/sun_akdpusoarkhvznjg.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (165, 4200)
# highway/sun_bhcqciazzelbazep.jpg
# shape:  (281, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (166, 4200)
# laundromat/sun_agpkwtvivpjrnjjq.jpg
# shape:  (500, 319, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (167, 4200)
# park/labelme_yyuizrwcvlbmqci.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (168, 4200)
# desert/sun_bcorncjicjbueeqd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (169, 4200)
# desert/sun_byobuhsgvryskzzl.jpg
# shape:  (339, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (170, 4200)
# park/sun_alstjednudtdzaoh.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (171, 4200)
# highway/sun_akihkricraebyttv.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (172, 4200)
# kitchen/sun_azpakouaxqyeukko.jpg
# shape:  (376, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (173, 4200)
# waterfall/sun_bwuyaszivxsqqcgw.jpg
# shape:  (313, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (174, 4200)
# kitchen/sun_asxolzqcqtihmbju.jpg
# shape:  (402, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (175, 4200)
# park/sun_aiihiolbbpbkovip.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (176, 4200)
# highway/sun_bgbooicntiiexavj.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (177, 4200)
# laundromat/sun_aeirvmvohzmvqmja.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (178, 4200)
# park/sun_aitrzglvqgozzaur.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (179, 4200)
# laundromat/sun_abueyoajufbkraki.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (180, 4200)
# highway/sun_bvfqjpglugjjkcnp.jpg
# shape:  (400, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (181, 4200)
# highway/sun_ajnnhysfapgbcweh.jpg
# shape:  (230, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (182, 4200)
# aquarium/sun_auxuxzrqwkdkbbdn.jpg
# shape:  (320, 260, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (183, 4200)
# windmill/sun_bieegjuywlwvuutx.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (184, 4200)
# waterfall/sun_azbubpstyfljlbms.jpg
# shape:  (348, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (185, 4200)
# aquarium/sun_azuqvyqqvdohwdef.jpg
# shape:  (500, 333, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (186, 4200)
# desert/sun_baworjhprekraztl.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (187, 4200)
# kitchen/sun_aholydgigohowhui.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (188, 4200)
# aquarium/sun_ahbydirwmqznizud.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (189, 4200)
# waterfall/sun_begqmgtlnyhedlpy.jpg
# shape:  (300, 225, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (190, 4200)
# desert/sun_bgljoorbdyvrmzct.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (191, 4200)
# waterfall/sun_astyypoygkaylvzt.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (192, 4200)
# desert/sun_azyhnyttxejyxrpi.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (193, 4200)
# desert/sun_bykopauyjbtnwwdw.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (194, 4200)
# highway/sun_bdwgezrbolobluib.jpg
# shape:  (369, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (195, 4200)
# highway/sun_bvsfqycnfyjlkujl.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (196, 4200)
# kitchen/sun_auyrvbsgjzcbllwy.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (197, 4200)
# desert/sun_bvlihuzwolttdrnn.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (198, 4200)
# kitchen/sun_aqrghqjleotcfoqp.jpg
# shape:  (336, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (199, 4200)
# highway/sun_bsvqxntvvsbowajp.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (200, 4200)
# windmill/sun_bkclwjhrbejydtyl.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (201, 4200)
# laundromat/sun_aywdgjrfarwaasdx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (202, 4200)
# desert/sun_azscfgaydhrrwvvg.jpg
# shape:  (325, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (203, 4200)
# aquarium/sun_ajqrylamgrartlmr.jpg
# shape:  (343, 470, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (204, 4200)
# park/sun_atroomuyehkexbyc.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (205, 4200)
# desert/sun_bfpcazteuhfurzuu.jpg
# shape:  (281, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (206, 4200)
# park/labelme_wjxputzultzgxie.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (207, 4200)
# laundromat/sun_avrcqwihsvomlmkz.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (208, 4200)
# park/labelme_brrdxeoavpkqjzs.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (209, 4200)
# windmill/sun_bwmasbhvnvcpjzva.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (210, 4200)
# laundromat/sun_ailkrcpigmkhnqkm.jpg
# shape:  (374, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (211, 4200)
# aquarium/sun_aunixsaxzlrueygg.jpg
# shape:  (284, 230, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (212, 4200)
# windmill/sun_bdrjeendbkbiupuf.jpg
# shape:  (329, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (213, 4200)
# waterfall/sun_ajezvlkzdsjjdnjm.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (214, 4200)
# desert/sun_bynuhpbketqvxudd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (215, 4200)
# aquarium/sun_azipgwtixazwwduo.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (216, 4200)
# laundromat/sun_auuqfgwjayuyytxw.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (217, 4200)
# waterfall/sun_aeqtojpozztmsvjg.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (218, 4200)
# park/sun_ashycthiyhkiydtr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (219, 4200)
# windmill/sun_bqgmvfkopapqmvgt.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (220, 4200)
# park/sun_aeiywlpqbvxjcwnd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (221, 4200)
# kitchen/sun_aasmevtpkslccptd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (222, 4200)
# aquarium/sun_alzyzabosxqgwavq.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (223, 4200)
# kitchen/sun_avjbidbdqqcnrdva.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (224, 4200)
# kitchen/sun_agrhekhltqnhqoau.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (225, 4200)
# park/sun_ajirvtmyllwmubkx.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (226, 4200)
# desert/sun_aijjkofxcvbaoewh.jpg
# shape:  (271, 393, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (227, 4200)
# park/sun_becmzguxoslmigcs.jpg
# shape:  (240, 320, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (228, 4200)
# highway/sun_buibjvcfrkzejmzn.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (229, 4200)
# kitchen/sun_ajgisfszhervnyxr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (230, 4200)
# aquarium/sun_aswmxnajswweurre.jpg
# shape:  (240, 320, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (231, 4200)
# desert/sun_awfhxzxcqoyqeyoo.jpg
# shape:  (500, 326, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (232, 4200)
# park/labelme_uwpcyhhlxphawyp.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (233, 4200)
# kitchen/sun_aitugazcpdxlcexr.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (234, 4200)
# waterfall/sun_bwzkjyclonamrgog.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (235, 4200)
# windmill/sun_bmqshhkqkhyuocrt.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (236, 4200)
# aquarium/sun_atmkdjsbyxhzsbir.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (237, 4200)
# kitchen/sun_ahvpoenucqfbjkep.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (238, 4200)
# waterfall/sun_akkydjepwkbfxozh.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (239, 4200)
# highway/sun_bxizfflrazsaijap.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (240, 4200)
# windmill/sun_bswuimewqmjtguca.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (241, 4200)
# desert/sun_aqtstmhxxgspchdn.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (242, 4200)
# kitchen/sun_aptlcpaekbcptzde.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (243, 4200)
# windmill/sun_bbdyuhapzpygeqfw.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (244, 4200)
# waterfall/sun_akihhfvylreuhukq.jpg
# shape:  (270, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (245, 4200)
# kitchen/sun_ahhmmwztdtudiqja.jpg
# shape:  (335, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (246, 4200)
# kitchen/sun_azkalqubuavyhanp.jpg
# shape:  (500, 464, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (247, 4200)
# aquarium/sun_avuuhyyjdrhcfzlu.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (248, 4200)
# laundromat/sun_akherkavsiteuceb.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (249, 4200)
# highway/sun_brllvepgzhutxfbv.jpg
# shape:  (268, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (250, 4200)
# aquarium/sun_anwxoraxuchsbjnx.jpg
# shape:  (300, 205, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (251, 4200)
# kitchen/sun_awhvlirgpcdffbsk.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (252, 4200)
# park/sun_acjydjytrumkfehr.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (253, 4200)
# aquarium/sun_acusadxqppxaqouk.jpg
# shape:  (267, 400, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (254, 4200)
# waterfall/sun_btyesquxyytxifkc.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (255, 4200)
# aquarium/sun_afmfomfbffcelkzr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (256, 4200)
# desert/sun_advllqdtdaefsajw.jpg
# shape:  (500, 327, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (257, 4200)
# aquarium/sun_asgtepdmsxsrqqvy.jpg
# shape:  (419, 288, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (258, 4200)
# highway/sun_bcsfqzqxmxsxejtu.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (259, 4200)
# kitchen/sun_avercuwadimcdyrt.jpg
# shape:  (435, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (260, 4200)
# park/sun_aqeryumwccopqznm.jpg
# shape:  (350, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (261, 4200)
# aquarium/sun_asqkigtqvxddevax.jpg
# shape:  (287, 432, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (262, 4200)
# windmill/sun_bremyoxdzsqpgoah.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (263, 4200)
# kitchen/sun_ataniphupyuxeowc.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (264, 4200)
# windmill/sun_bwnuhqwpijnoclhf.jpg
# shape:  (365, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (265, 4200)
# laundromat/sun_atylnjiiotbbzerb.jpg
# shape:  (500, 344, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (266, 4200)
# kitchen/sun_ahqrrgokszxtlsyi.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (267, 4200)
# kitchen/sun_azgxmfkamfoixcqm.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (268, 4200)
# windmill/sun_bdtchkepcotagfds.jpg
# shape:  (500, 333, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (269, 4200)
# waterfall/sun_aghcxbzinxkqdans.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (270, 4200)
# windmill/sun_bawsdjisukbbginm.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (271, 4200)
# windmill/sun_bnpnvabmtnsnliok.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (272, 4200)
# windmill/sun_bxbotnklezmeidrd.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (273, 4200)
# park/sun_bfruscgbtatjlcjw.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (274, 4200)
# laundromat/sun_aohsctlguthyugrm.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (275, 4200)
# highway/sun_bjkgqyyvybgdukip.jpg
# shape:  (371, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (276, 4200)
# kitchen/sun_ancbszwardammcpi.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (277, 4200)
# aquarium/sun_abjhcwfgisiwsrcz.jpg
# shape:  (225, 300, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (278, 4200)
# desert/sun_afnezlyrmmdropae.jpg
# shape:  (340, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (279, 4200)
# waterfall/sun_axarixzmoshhrhlt.jpg
# shape:  (256, 257, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (280, 4200)
# park/sun_avptxqehhfcbqkam.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (281, 4200)
# waterfall/sun_btpaxygvjiqfrsvs.jpg
# shape:  (366, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (282, 4200)
# windmill/sun_bjckaogrdqdmedgw.jpg
# shape:  (313, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (283, 4200)
# aquarium/sun_aoznvhxxhtfpldpr.jpg
# shape:  (225, 300, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (284, 4200)
# laundromat/sun_awalujgzchfemmlk.jpg
# shape:  (377, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (285, 4200)
# highway/sun_bqxkmpespujtvovh.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (286, 4200)
# waterfall/sun_adtiwvbnsxsyohuw.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (287, 4200)
# kitchen/sun_ayakdnbiuvnibwap.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (288, 4200)
# highway/sun_blghdewmpheqljet.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (289, 4200)
# desert/sun_bqpgzqwdglfssiyq.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (290, 4200)
# windmill/sun_bhrmxenchvwhgxzk.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (291, 4200)
# highway/sun_bpjykrpgbxoahhxi.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (292, 4200)
# desert/sun_bxrzqybxvploelui.jpg
# shape:  (286, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (293, 4200)
# kitchen/sun_arlfirewzdyuqbot.jpg
# shape:  (338, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (294, 4200)
# laundromat/sun_azodrfvndjojnddr.jpg
# shape:  (281, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (295, 4200)
# desert/sun_bhsmphhtedtwkkrc.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (296, 4200)
# desert/sun_bwvfftwqwfbjqmmu.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (297, 4200)
# laundromat/sun_awrgdubeirotmeuc.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (298, 4200)
# laundromat/sun_aipybnczjgsffbdw.jpg
# shape:  (387, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (299, 4200)
# highway/sun_bahbelqhmdpyqzlj.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (300, 4200)
# kitchen/sun_adjgnpenryftfwsr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (301, 4200)
# desert/sun_aqyniglpvhrfleus.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (302, 4200)
# laundromat/sun_aggbfkjrmpydkimu.jpg
# shape:  (381, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (303, 4200)
# aquarium/sun_assowsvzwlkzpksk.jpg
# shape:  (349, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (304, 4200)
# desert/sun_aujybsndkefrqulc.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (305, 4200)
# highway/sun_bivmxxnwlvluqpxb.jpg
# shape:  (286, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (306, 4200)
# waterfall/sun_awlieccocberhyff.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (307, 4200)
# windmill/sun_binhopircnulazxm.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (308, 4200)
# kitchen/sun_aiwjjxhtgtrwjdsf.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (309, 4200)
# aquarium/sun_akjpgxvhcvynabhn.jpg
# shape:  (332, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (310, 4200)
# highway/sun_bckdoczbyyhytoxk.jpg
# shape:  (223, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (311, 4200)
# highway/sun_bxosbnnrnrtpxywp.jpg
# shape:  (332, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (312, 4200)
# windmill/sun_bibbtuglzvqmkpdj.jpg
# shape:  (335, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (313, 4200)
# desert/sun_bkcdatqxdazovlgp.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (314, 4200)
# kitchen/sun_awqncsdprzjtqkum.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (315, 4200)
# desert/sun_buzptenhhzbfkklk.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (316, 4200)
# aquarium/sun_axupplqbnrgiuzwi.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (317, 4200)
# desert/sun_bafqfjpechscyidz.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (318, 4200)
# park/labelme_oztzgiwbormrfew.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (319, 4200)
# park/sun_ajrktderomddeusb.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (320, 4200)
# windmill/sun_byiucsczkegtlfot.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (321, 4200)
# desert/sun_bqljzuxtzgthsjqt.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (322, 4200)
# desert/sun_adfzvpneqfqbfcnq.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (323, 4200)
# highway/sun_bykopigkkfxmnoty.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (324, 4200)
# park/sun_ahavybdisugxhilq.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (325, 4200)
# laundromat/sun_arxaunnwelmcrppb.jpg
# shape:  (500, 386, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (326, 4200)
# highway/sun_brfridtpazxwwvqo.jpg
# shape:  (408, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (327, 4200)
# windmill/sun_bhexonkjpkebkqou.jpg
# shape:  (309, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (328, 4200)
# aquarium/sun_akyriexvlsmqmlcr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (329, 4200)
# windmill/sun_bywyjkswjffkxkgq.jpg
# shape:  (500, 350, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (330, 4200)
# desert/sun_affqedumnyoalmru.jpg
# shape:  (356, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (331, 4200)
# highway/sun_btvxhvfdasqqctmj.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (332, 4200)
# aquarium/sun_auspgqfzudtrefsw.jpg
# shape:  (346, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (333, 4200)
# kitchen/sun_anbqoyitlozwisvu.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (334, 4200)
# highway/sun_bmrbvvjbxrdvtwig.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (335, 4200)
# kitchen/sun_anmjjrhxyxewngxm.jpg
# shape:  (500, 338, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (336, 4200)
# park/labelme_xlilyvvcptgtfpm.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (337, 4200)
# park/labelme_wgyadeanwhhmcrw.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (338, 4200)
# kitchen/sun_abrhpazvtygrpabg.jpg
# shape:  (335, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (339, 4200)
# desert/sun_abdulxymarqnjwgh.jpg
# shape:  (327, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (340, 4200)
# desert/sun_bpyghcqtrpqnabei.jpg
# shape:  (339, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (341, 4200)
# highway/sun_biavuxoxidyuogrd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (342, 4200)
# laundromat/sun_aqujzbmrvqqrklrv.jpg
# shape:  (344, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (343, 4200)
# park/sun_bbjxopwoqkmqrdjn.jpg
# shape:  (283, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (344, 4200)
# laundromat/sun_axsxemuqtdinhlud.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (345, 4200)
# laundromat/sun_aeubzrtqhnhtsfyr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (346, 4200)
# aquarium/sun_aouppctgqwahpgua.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (347, 4200)
# highway/sun_aismwztcmdyhphdl.jpg
# shape:  (500, 425, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (348, 4200)
# park/sun_achgmbemgnuebnik.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (349, 4200)
# desert/sun_bnvjjlyzatkvovei.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (350, 4200)
# kitchen/sun_aobyfgpmnvnnuolx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (351, 4200)
# desert/sun_akvwwvuzoytbjnux.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (352, 4200)
# windmill/sun_btogttthhaffpfcl.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (353, 4200)
# desert/sun_bxnbluncjbawbkgg.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (354, 4200)
# laundromat/sun_atgwwtsbjqjwqlzh.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (355, 4200)
# highway/sun_byltiwxlutgvnafl.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (356, 4200)
# windmill/sun_bordwkstdxaptutf.jpg
# shape:  (379, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (357, 4200)
# laundromat/sun_atxsxasjhbdfzaby.jpg
# shape:  (373, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (358, 4200)
# laundromat/sun_amyplhplxiebsohm.jpg
# shape:  (500, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (359, 4200)
# highway/sun_bmvnfevgdudafhit.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (360, 4200)
# aquarium/sun_agpbzgcntsclwmci.jpg
# shape:  (376, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (361, 4200)
# park/labelme_rvultxdvihvgfuh.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (362, 4200)
# windmill/sun_bxpvmlxprftjwynu.jpg
# shape:  (420, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (363, 4200)
# laundromat/sun_awoswtyoyrtajzdx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (364, 4200)
# kitchen/sun_aglwoufpxbtxqecp.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (365, 4200)
# waterfall/sun_avjotscqfvyeeqxi.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (366, 4200)
# ...
# Shape of Feature:  (879, 4200)
# kitchen/sun_aibgyrlkgcnwvhxl.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (880, 4200)
# laundromat/sun_abvamapncxhqvhxg.jpg
# shape:  (376, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (881, 4200)
# windmill/sun_bnaycfkbladudnfz.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (882, 4200)
# desert/sun_bdfjllgwodlyospl.jpg
# shape:  (271, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (883, 4200)
# park/sun_apbktgbaphrrowtq.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (884, 4200)
# highway/sun_bbklfhkdkceatnzv.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (885, 4200)
# park/sun_aphlpasnplzacprj.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (886, 4200)
# aquarium/sun_ayjobgyanrtaypba.jpg
# shape:  (234, 419, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (887, 4200)
# desert/sun_bssrzuslposilujg.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (888, 4200)
# highway/sun_bckmblqgdjkaojjd.jpg
# shape:  (313, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (889, 4200)
# waterfall/sun_advocchixohdoito.jpg
# shape:  (256, 257, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (890, 4200)
# windmill/sun_bkjhovqagpfknkax.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (891, 4200)
# kitchen/sun_aqnawptdptzkbvlq.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (892, 4200)
# waterfall/sun_btjjalgedyognjhs.jpg
# shape:  (500, 376, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (893, 4200)
# waterfall/sun_aqpeoitrthbnhttq.jpg
# shape:  (256, 257, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (894, 4200)
# laundromat/sun_aqiysngbtmumsnsj.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (895, 4200)
# park/sun_aanruhprskxpwhzm.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (896, 4200)
# aquarium/sun_aaqwqkwglsmkulks.jpg
# shape:  (352, 450, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (897, 4200)
# aquarium/sun_aplanrcansyfdcmj.jpg
# shape:  (319, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (898, 4200)
# kitchen/sun_anjplxxhrqpqpzlr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (899, 4200)
# windmill/sun_bchpbzziewihscmg.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (900, 4200)
# highway/sun_bpflsdaxnddnwcqi.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (901, 4200)
# windmill/sun_bcwhmudmnebnozjq.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (902, 4200)
# waterfall/sun_basayezunqjbbjwj.jpg
# shape:  (329, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (903, 4200)
# desert/sun_bzpjfetivojhplyc.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (904, 4200)
# windmill/sun_bedjfgkztzksgrih.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (905, 4200)
# highway/sun_btvskgegczcrfwwa.jpg
# shape:  (373, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (906, 4200)
# waterfall/sun_aastyysdvtnkdcvt.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (907, 4200)
# kitchen/sun_atgzwnczaxwddrai.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (908, 4200)
# laundromat/sun_aodwvqchicnebypb.jpg
# shape:  (200, 305, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (909, 4200)
# aquarium/sun_akfrnesxfdlceikn.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (910, 4200)
# park/labelme_hkwpzfvrgmkpucv.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (911, 4200)
# waterfall/sun_anjjpkyqixrxafks.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (912, 4200)
# windmill/sun_bvewelgxucntjgbl.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (913, 4200)
# windmill/sun_bwxykjnkhsgztqwq.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (914, 4200)
# park/sun_avdpqlyeusvgmaze.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (915, 4200)
# windmill/sun_bqklimybnopxqcqx.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (916, 4200)
# laundromat/sun_ayfdfjxkfstwnvuj.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (917, 4200)
# waterfall/sun_aokliiyteekpcvst.jpg
# shape:  (332, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (918, 4200)
# aquarium/sun_aairflxfskjrkepm.jpg
# shape:  (309, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (919, 4200)
# kitchen/sun_aqlscylvundyqoxd.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (920, 4200)
# laundromat/sun_atsjwquszjtylnny.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (921, 4200)
# kitchen/sun_avummurlcrknzblj.jpg
# shape:  (500, 476, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (922, 4200)
# aquarium/sun_aehmjtxdcbybzxor.jpg
# shape:  (360, 240, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (923, 4200)
# park/sun_adpzpwzanrhtbyvc.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (924, 4200)
# waterfall/sun_brvzopcyvrklmmqg.jpg
# shape:  (300, 300, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (925, 4200)
# aquarium/sun_axftbpasnkrpiacj.jpg
# shape:  (320, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (926, 4200)
# waterfall/sun_aqlrhdmixnakvcfq.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (927, 4200)
# park/labelme_entwioeipyqzcaa.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (928, 4200)
# aquarium/sun_absyhasrllbhqcic.jpg
# shape:  (383, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (929, 4200)
# aquarium/sun_avdirymfvklsislz.jpg
# shape:  (230, 370, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (930, 4200)
# waterfall/sun_azgsefkpcledvfrc.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (931, 4200)
# kitchen/sun_ajsmhdhzrfaanynl.jpg
# shape:  (377, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (932, 4200)
# kitchen/sun_ajomvdpkryvawqyv.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (933, 4200)
# kitchen/sun_aawefvrbscajixha.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (934, 4200)
# kitchen/sun_agldadusrezhmyva.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (935, 4200)
# waterfall/sun_bxbqnskmvvidhmcj.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (936, 4200)
# waterfall/sun_andvaoamnpthswld.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (937, 4200)
# kitchen/sun_asohlbchxzzgeruw.jpg
# shape:  (500, 296, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (938, 4200)
# aquarium/sun_aamlnkpomzzujqpa.jpg
# shape:  (500, 293, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (939, 4200)
# aquarium/sun_afwqgnysmjcdivth.jpg
# shape:  (289, 410, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (940, 4200)
# desert/sun_beejycwcershxzno.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (941, 4200)
# kitchen/sun_akwvdhqsbtcesevi.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (942, 4200)
# desert/sun_blwrfglpkhxpenia.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (943, 4200)
# park/labelme_oxgxgzccrwgozgh.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (944, 4200)
# highway/sun_bnvaatlldzndddpg.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (945, 4200)
# aquarium/sun_aashbnpnxflmstxu.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (946, 4200)
# desert/sun_baiqcjaunzuqiswb.jpg
# shape:  (348, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (947, 4200)
# park/sun_aerlsgdmowltbanb.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (948, 4200)
# laundromat/sun_anqwbehjngxxefif.jpg
# shape:  (370, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (949, 4200)
# park/labelme_cithqzoasedbpyd.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (950, 4200)
# aquarium/sun_ahrxcwjnvedrgxkw.jpg
# shape:  (363, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (951, 4200)
# laundromat/sun_apeewlgitxqsqlsh.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (952, 4200)
# waterfall/sun_bvoraywiwkghtfsp.jpg
# shape:  (334, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (953, 4200)
# desert/sun_btidxypsdyearnbr.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (954, 4200)
# windmill/sun_bzlhecxwklziwzpp.jpg
# shape:  (500, 338, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (955, 4200)
# laundromat/sun_auujynepkdhhhsya.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (956, 4200)
# kitchen/sun_abjllhhfuvcygwtk.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (957, 4200)
# highway/sun_baxahfrqnlwlqxkr.jpg
# shape:  (377, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (958, 4200)
# kitchen/sun_agzyxoehwtiyumly.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (959, 4200)
# park/sun_ayoirgsmgenoyfwd.jpg
# shape:  (360, 480, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (960, 4200)
# laundromat/sun_ajpiazmxntyazoeu.jpg
# shape:  (500, 333, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (961, 4200)
# laundromat/sun_azokvxeqnmbwkias.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (962, 4200)
# highway/sun_bzyaprkmgxuvvphb.jpg
# shape:  (353, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (963, 4200)
# windmill/sun_byohwgzbysggvehb.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (964, 4200)
# highway/sun_bjqewvnqhqprwynz.jpg
# shape:  (350, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (965, 4200)
# waterfall/sun_bjgujnjeakwxtjtz.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (966, 4200)
# windmill/sun_bvtbnfulhkixbvev.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (967, 4200)
# aquarium/sun_auqfioruanbaaarh.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (968, 4200)
# highway/sun_bmeycokvfcwgkjzp.jpg
# shape:  (373, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (969, 4200)
# kitchen/sun_antnldfudmkiluww.jpg
# shape:  (500, 437, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (970, 4200)
# windmill/sun_bvzmgrdvaakxusbu.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (971, 4200)
# waterfall/sun_aexrqfnsxznqntss.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (972, 4200)
# highway/sun_boziybrhsxkeuasq.jpg
# shape:  (373, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (973, 4200)
# waterfall/sun_bzhutghtpzehkewp.jpg
# shape:  (272, 250, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (974, 4200)
# highway/sun_advstbacygihnsur.jpg
# shape:  (335, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (975, 4200)
# desert/sun_bpsoapwdsvvtfiry.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (976, 4200)
# laundromat/sun_auhtiqbpghdmainu.jpg
# shape:  (332, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (977, 4200)
# laundromat/sun_arvqzetpuylopyxo.jpg
# shape:  (333, 499, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (978, 4200)
# aquarium/sun_adwaeavjzaxfgowq.jpg
# shape:  (336, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (979, 4200)
# kitchen/sun_abujclohwuaugvev.jpg
# shape:  (396, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (980, 4200)
# park/labelme_gwdhrnqpqambofu.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (981, 4200)
# laundromat/sun_atqqoakhkgncspji.jpg
# shape:  (370, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (982, 4200)
# laundromat/sun_awitbbmzsrbvkkds.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (983, 4200)
# desert/sun_bmmajwuuvxosfarp.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (984, 4200)
# park/sun_avuvisjaftfmkkbi.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (985, 4200)
# kitchen/sun_arffihzwrfsleobm.jpg
# shape:  (443, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (986, 4200)
# highway/sun_bloieyiimdhyurxq.jpg
# shape:  (274, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (987, 4200)
# aquarium/sun_abilrnmvvpwtaono.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (988, 4200)
# windmill/sun_bgevvxyaoknnwbyn.jpg
# shape:  (500, 375, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (989, 4200)
# laundromat/sun_abdvppgytzcuptzn.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (990, 4200)
# park/sun_arqwdidhupkgonho.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (991, 4200)
# waterfall/sun_bnkwfeagylofucir.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (992, 4200)
# kitchen/sun_adthtuhxofgeohjs.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (993, 4200)
# windmill/sun_bhkywweriavdjvio.jpg
# shape:  (500, 334, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (994, 4200)
# aquarium/sun_aztvjgubyrgvirup.jpg
# shape:  (310, 444, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (995, 4200)
# aquarium/sun_aueaalblfowrtvxb.jpg
# shape:  (225, 300, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (996, 4200)
# waterfall/sun_ailkshkaldwakifp.jpg
# shape:  (256, 256, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (997, 4200)
# laundromat/sun_axkxqjyfxdedbcxf.jpg
# shape:  (333, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (998, 4200)
# laundromat/sun_aosteksswkpwvhol.jpg
# shape:  (375, 500, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (999, 4200)
# kitchen/sun_akgguqilufnjugzk.jpg
# shape:  (500, 282, 12)
# 60
# 200
# Shape of Ordered Feature:  (1, 4200)
# Shape of Feature:  (1000, 4200)

# %% [markdown]
# ### References
#
# [1]  James Hays and Alexei A Efros. Scene completion using millions of photographs.ACM Transactions onGraphics (SIGGRAPH 2007), 26(3), 2007.
#
# [2]  S. Lazebnik, C. Schmid, and J. Ponce. Beyond bags of features: Spatial pyramid matching for recogniz-ing natural scene categories.  InComputer Vision and Pattern Recognition (CVPR), 2006 IEEE Conferenceon, volume 2, pages 2169–2178, 2006.
#
# [3]  Jian xiong Xiao, J. Hays, K. Ehinger, A. Oliva, and A. Torralba. Sun database: Large-scale scene recogni-tion from abbey to zoo.2010 IEEE Computer Society Conference on Computer Vision and Pattern Recognition,pages 3485–3492, 2010.14
